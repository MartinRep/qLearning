# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_eps = pd.read_csv('output/log.csv', header=0)

# %%
fig, ax1 = plt.subplots(ncols=1, sharey=True)
fig.set_size_inches(20, 20)
ax1.set_title('Q learning GridWorld')
sns.lineplot(x='episode', y='steps', data=df_eps)
